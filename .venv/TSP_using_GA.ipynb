# %%
import random
import math
# Generate population size in each generation
population_size = 100
n = int(input())

# %%
class Path:
    def __init__(self, string):
        self.string = string
        self.fitness = self.calculate_fitness()
    #Calculate fitness
    def calculate_fitness(self):
        fitness = 0
        for i in range(1, len(self.string)):
            distance = math.sqrt((dict[self.string[i]][0] - dict[self.string[i-1]][0])**2 + (dict[self.string[i]][1] - dict[self.string[i-1]][1])**2)
            fitness += distance
        return fitness
    #Check if whether the city in the path
    @classmethod
    def repeat(self, string, ch):
        if ch in string:
            return True
        return False
    @classmethod
    def random_genes(self):
        string = "0"
        while True:
            if len(string) == n:
                string += string[0]
                break

            temp = random.randint(1, n-1)
            if not self.repeat(string, chr(temp + 48)):
                string += chr(temp + 48)

        return string
    def mate(self, parent):
        child_string = []
        for child1, child2 in zip(self.string, parent.string):
            if not self.repeat(child_string, child1) and not self.repeat(child_string,child2):
                prob = random.random()
                if prob < 0.5:
                    child_string.append(child1)
                else:
                    child_string.append(child2)
            elif not self.repeat(child_string, child1):
                child_string.append(child1)
            elif not self.repeat(child_string,child2):
                child_string.append(child2)
            else:    
                for i in range(1, n):
                    if chr(i+48) not in child_string:
                        child_string.append(chr(i+48))
                        break
        child_string.append('0')
        return Path(child_string)

# %%
# Randomize the place of each city
dict = {chr(i+48): [random.randint(1,999), random.randint(1,999)] for i in range(n)}
generation = 1
iterations = 80
population = []
for i in range(population_size):
    random_path = Path(Path.random_genes())
    population.append(random_path)
while iterations > 0:
    iterations -= 1
    population = sorted(population, key=lambda x: x.fitness)
    print(f'Generation: {generation}  String: {"".join(population[0].string)}  Fitness: {population[0].fitness}')
    new_population = []
    new_population.extend(population[:10])
    for i in range(int(population_size*90/100)):
        par1 = random.choice(population[:50])
        par2 = random.choice(population[:50])
        child = par1.mate(par2)
        new_population.append(child)
    population = new_population
    generation += 1
# Out:
# Generation: 1  String: 0A>=L8:6@E5IB9J73HDMFK4;?C<G210  Fitness: 12525.211517479762
# Generation: 2  String: 0A>=L8:6@E5IB9J73HDMFK4;?C<G210  Fitness: 12525.211517479762
# Generation: 3  String: 0A>=L8:6@E5IB9J73HDMFK4;?C<G210  Fitness: 12525.211517479762
# Generation: 4  String: 0A>=L8:6@E5IB9J73HDMFK4;?C<G210  Fitness: 12525.211517479762
# Generation: 5  String: 013:K275@F849C?HME6<JLG;=>DAIB0  Fitness: 12194.76124298622
# Generation: 6  String: 017K286@GFI49:JH>EM<5LCDA3B;=?0  Fitness: 11638.604972911347
# Generation: 7  String: 017K286@GFI49:JH>EM<5LCDA3B;=?0  Fitness: 11638.604972911347
# Generation: 8  String: 017K286@GFI49:JH>EM<5LCDA3B;=?0  Fitness: 11638.604972911347
# Generation: 9  String: 01BK8>6@;2F79345ME:JG<D=?IACHL0  Fitness: 11397.723499028289
# Generation: 10  String: 017:KB9@GFI42CJ5ME6<3;=DA>?H8L0  Fitness: 11148.38906860168
# Generation: 11  String: 013:KB5@GFI42CMH6E<97=8;?AD>JL0  Fitness: 10748.409142959223
# Generation: 12  String: 013:KB5@GFI42CMH6E<97=8;?AD>JL0  Fitness: 10748.409142959223
# Generation: 13  String: 013:KB5@GFI42CMH6E<97=8;?AD>JL0  Fitness: 10748.409142959223
# Generation: 14  String: 017KCM6@;FI43:JH>E8<L9BD=2A?G50  Fitness: 10432.147218478283
# Generation: 15  String: 017JKB6@;FI4925HME<3L:CDA8>G=?0  Fitness: 10033.019462263808
# Generation: 16  String: 017JKB6@;FI4925HME<3L:CDA8>G=?0  Fitness: 10033.019462263808
# Generation: 17  String: 017JKB6@;FI4925HME<3L:CDA8>G=?0  Fitness: 10033.019462263808
# Generation: 18  String: 017JKB6@;FI4925HME<3L:CDA8>G=?0  Fitness: 10033.019462263808
# Generation: 19  String: 017JCM6@GFI42:35>E<KL9BD=;?H8A0  Fitness: 9905.812080832076
# Generation: 20  String: 017JCM6@GFI42:35>E<KL9BD=;?H8A0  Fitness: 9905.812080832076
# Generation: 21  String: 017JCM6@GFI42:35>E<KL9BD=;?H8A0  Fitness: 9905.812080832076
# Generation: 22  String: 017KC>6@GFI4935HME<JL:BD=;?28A0  Fitness: 9182.207893443072
# Generation: 23  String: 017KC>6@GFI4935HME<JL:BD=;?28A0  Fitness: 9182.207893443072
# Generation: 24  String: 017KC>6@GFI4935HME<JL:BD=;?28A0  Fitness: 9182.207893443072
# Generation: 25  String: 017KC>6@GFI4935HME<JL:BD=;?28A0  Fitness: 9182.207893443072
# Generation: 26  String: 017KCM6@GFI4935H>E<JL:BD=;?28A0  Fitness: 9097.438175582842
# Generation: 27  String: 017KCM6@GFI4935H>E<JL:BD=;?28A0  Fitness: 9097.438175582842
# Generation: 28  String: 017KCM6@GFI4935H>E<JL:BD=;?28A0  Fitness: 9097.438175582842
# Generation: 29  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 30  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 31  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 32  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 33  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 34  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 35  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 36  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 37  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 38  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 39  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 40  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 41  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 42  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 43  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 44  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 45  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 46  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 47  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 48  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 49  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 50  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 51  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 52  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 53  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 54  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 55  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 56  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 57  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 58  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 59  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 60  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 61  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 62  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 63  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 64  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 65  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 66  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 67  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 68  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 69  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 70  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 71  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 72  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 73  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 74  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 75  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 76  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 77  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 78  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 79  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
# Generation: 80  String: 017KCM6@GFI4B35H>E<JL9:D=;?28A0  Fitness: 8820.81214829646
